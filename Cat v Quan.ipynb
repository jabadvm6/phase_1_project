# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
# seaborn is going to be your friend
import seaborn as sns

# %%
df = pd.read_csv("netgen.csv")

# %%
df
# Out:
#       genres  start_year         id  production_budget  domestic_gross  \
# 0     Action      2010.0  50.738462       5.718138e+07    5.933221e+07
# 1     Action      2011.0  49.441176       5.712338e+07    5.544213e+07
# 2     Action      2012.0  47.769231       6.870615e+07    7.616046e+07
# 3     Action      2013.0  48.484375       7.047422e+07    6.875841e+07
# 4     Action      2014.0  50.752809       5.837865e+07    7.390198e+07
# ..       ...         ...        ...                ...             ...
# 206  Western      2014.0  50.000000       6.433333e+06    8.298950e+05
# 207  Western      2015.0  39.333333       3.433333e+07    5.045977e+05
# 208  Western      2016.0  55.000000       9.000000e+07    9.343266e+07
# 209  Western      2018.0  53.000000       1.200000e+07    6.553258e+07
# 210  Western      2019.0  94.000000       6.500000e+07    6.968838e+07
#
#      worldwide_gross     Net Gross  runtime_minutes     net_gross
# 0       1.372413e+08  8.005991e+07       103.938462  8.005991e+07
# 1       1.580846e+08  1.009612e+08       109.661765  1.009612e+08
# 2       1.909614e+08  1.222552e+08       108.769231  1.222552e+08
# 3       1.760460e+08  1.055717e+08       113.500000  1.055717e+08
# 4       1.992769e+08  1.408983e+08       109.786517  1.408983e+08
# ..               ...           ...              ...           ...
# 206     2.759089e+06 -3.674244e+06       103.000000 -3.674244e+06
# 207     1.257115e+06 -3.307622e+07       102.333333 -3.307622e+07
# 208     1.625252e+08  7.252516e+07       132.000000  7.252516e+07
# 209     6.553258e+07  5.353258e+07        67.000000  5.353258e+07
# 210     6.968838e+07  4.688384e+06       100.000000  4.688384e+06
#
# [211 rows x 9 columns]

# %%
budget_df = pd.read_csv("zippedData/tn.movie_budgets.csv.gz")

# %%
budget_df
# Out:
#       id  release_date                                primary_title  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5777               7000               0                0
# 5778               6000           48482           240495
# 5779               5000            1338             1338
# 5780               1400               0                0
# 5781               1100          181041           181041
#
# [5782 rows x 6 columns]

# %%
budget_df['production_budget'] = budget_df['production_budget'].str.replace(",","")
budget_df['production_budget'] = budget_df['production_budget'].str.replace("$","")
budget_df['domestic_gross'] = budget_df['domestic_gross'].str.replace(",","")
budget_df['domestic_gross'] = budget_df['domestic_gross'].str.replace("$","")
budget_df['worldwide_gross'] = budget_df['worldwide_gross'].str.replace(",","")
budget_df['worldwide_gross'] = budget_df['worldwide_gross'].str.replace("$","")

# %%
budget_df['domestic_gross'] = budget_df['domestic_gross'].apply(lambda x: int(x))
budget_df['production_budget'] = budget_df['production_budget'].apply(lambda x: int(x))
budget_df['worldwide_gross'] = budget_df['worldwide_gross'].apply(lambda x: int(x))

# %%
con = sqlite3.connect("zippedData/im.db/im.db")

cur = con.cursor()

# %%
persons_df = pd.read_sql("""
SELECT *
FROM persons
""",con)

# %%
pri_per_df = pd.read_sql("""
SELECT *
FROM principals
LEFT JOIN persons
ON principals.person_id = persons.person_id
""",con)

# %%
reviews_df = pd.read_csv("review_dataframe.csv")

# %%
reviews_df = reviews_df.set_index('movie_id')
pri_per_df = pri_per_df.set_index('movie_id')

# %%
imdb_df = pri_per_df.merge(reviews_df, on = "movie_id", how = "left")

# %%
imdb_df = imdb_df.drop(["job",'characters','birth_year','death_year','Unnamed: 0'],axis = 1)

# %%
imdb_df = imdb_df.dropna(subset = ['genres'])

# %%
imdb_df["movie_id"] = imdb_df.index

# %%
imdb_df = imdb_df.set_index("primary_title", drop = False)

# %%
cols = imdb_df.columns.tolist()

# %%
cols_alt = ['movie_id', 'primary_title', 'original_title', 'genres', 'start_year', 'runtime_minutes', 'averagerating', 'ratingbyvotes', 'numvotes', 'ordering', 'person_id', 'primary_name', 'person_id', 'category', 'primary_profession']

# %%
cols_alt = ['movie_id', 'primary_title', 'original_title', 'genres', 'start_year', 'runtime_minutes', 'averagerating', 'numvotes', 'primary_name', 'category']

# %%
imdb_df_alt = imdb_df[cols_alt]

# %% [markdown]
# Analyzing data and adding budget below

# %%
imdb_df.to_csv('imdb_masterdata.csv')

# %%
imdb_df_alt.to_csv('imdb_masterdata.csv')

# %%
budget_df = budget_df.rename(columns={"movie": "primary_title"})

# %%
imdb_df_alt.reset_index(drop = True, inplace = True)

# %%
imdb_budget_df = imdb_df_alt.merge(budget_df, on = 'primary_title', how = "left")

# %%
imdb_budget_df = imdb_budget_df.dropna(subset = ['production_budget'])

# %%
imdb_budget_df["revenue"] = imdb_budget_df["worldwide_gross"] + imdb_budget_df["production_budget"]

# %%
imdb_budget_df['profit_margin'] = imdb_budget_df["worldwide_gross"] / imdb_budget_df["revenue"]

# %%
imdb_budget_df['release_date'] = imdb_budget_df['release_date'].astype('datetime64')

# %%
imdb_budget_df.to_csv('imdb_budget_data.csv')

# %%
imdb_budget_df
# Out:
#           movie_id  primary_title original_title  genres  start_year  \
# 40       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 41       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# 42       tt0475290  Hail, Caesar!  Hail, Caesar!   Music      2016.0
# 43       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 44       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# ...            ...            ...            ...     ...         ...
# 1026474  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026475  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026476  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026477  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026478  tt8662424    Never Again    Never Again   Drama      2017.0
#
#          runtime_minutes  averagerating  numvotes      primary_name  \
# 40                 106.0            6.3  111422.0     Roger Deakins
# 41                 106.0            6.3  111422.0     Roger Deakins
# 42                 106.0            6.3  111422.0     Roger Deakins
# 43                 106.0            6.3  111422.0       Josh Brolin
# 44                 106.0            6.3  111422.0       Josh Brolin
# ...                  ...            ...       ...               ...
# 1026474            106.0            5.7      67.0  Kristen Carletta
# 1026475            106.0            5.7      67.0        Jay Coster
# 1026476            106.0            5.7      67.0     Katie Watling
# 1026477            106.0            5.7      67.0      Ben Gordelia
# 1026478            106.0            5.7      67.0    Michael Wooley
#
#                 category    id release_date  production_budget  \
# 40       cinematographer  22.0   2016-02-05         22000000.0
# 41       cinematographer  22.0   2016-02-05         22000000.0
# 42       cinematographer  22.0   2016-02-05         22000000.0
# 43                 actor  22.0   2016-02-05         22000000.0
# 44                 actor  22.0   2016-02-05         22000000.0
# ...                  ...   ...          ...                ...
# 1026474          actress  47.0   2002-07-12           500000.0
# 1026475         director  47.0   2002-07-12           500000.0
# 1026476         producer  47.0   2002-07-12           500000.0
# 1026477         composer  47.0   2002-07-12           500000.0
# 1026478  cinematographer  47.0   2002-07-12           500000.0
#
#          domestic_gross  worldwide_gross     revenue  profit_margin
# 40           30080225.0       64160680.0  86160680.0       0.744663
# 41           30080225.0       64160680.0  86160680.0       0.744663
# 42           30080225.0       64160680.0  86160680.0       0.744663
# 43           30080225.0       64160680.0  86160680.0       0.744663
# 44           30080225.0       64160680.0  86160680.0       0.744663
# ...                 ...              ...         ...            ...
# 1026474        307631.0         308793.0    808793.0       0.381795
# 1026475        307631.0         308793.0    808793.0       0.381795
# 1026476        307631.0         308793.0    808793.0       0.381795
# 1026477        307631.0         308793.0    808793.0       0.381795
# 1026478        307631.0         308793.0    808793.0       0.381795
#
# [60594 rows x 17 columns]

# %%
imdb_df
# Out:
#                  ordering   person_id         category   person_id  \
# primary_title
# The Wicker Tree        10   nm0059247           editor   nm0059247
# The Wicker Tree        10   nm0059247           editor   nm0059247
# The Wicker Tree         1   nm3579312          actress   nm3579312
# The Wicker Tree         1   nm3579312          actress   nm3579312
# The Wicker Tree         2   nm2694680            actor   nm2694680
# ...                   ...         ...              ...         ...
# A Russian Youth         7   nm9645603  cinematographer   nm9645603
# A Russian Youth         8  nm10436663            actor  nm10436663
# A Russian Youth         8  nm10436663            actor  nm10436663
# A Russian Youth         9  nm10397910            actor  nm10397910
# A Russian Youth         9  nm10397910            actor  nm10397910
#
#                     primary_name  \
# primary_title
# The Wicker Tree      Sean Barton
# The Wicker Tree      Sean Barton
# The Wicker Tree  Brittania Nicol
# The Wicker Tree  Brittania Nicol
# The Wicker Tree    Henry Garrett
# ...                          ...
# A Russian Youth    Ayrat Yamilov
# A Russian Youth     Artem Leshik
# A Russian Youth     Artem Leshik
# A Russian Youth     Danil Tyabin
# A Russian Youth     Danil Tyabin
#
#                                              primary_profession  \
# primary_title
# The Wicker Tree  editor,editorial_department,assistant_director
# The Wicker Tree  editor,editorial_department,assistant_director
# The Wicker Tree                              actress,soundtrack
# The Wicker Tree                              actress,soundtrack
# The Wicker Tree                                           actor
# ...                                                         ...
# A Russian Youth                                 cinematographer
# A Russian Youth                                           actor
# A Russian Youth                                           actor
# A Russian Youth                                           actor
# A Russian Youth                                           actor
#
#                    primary_title   original_title  start_year  \
# primary_title
# The Wicker Tree  The Wicker Tree  The Wicker Tree      2011.0
# The Wicker Tree  The Wicker Tree  The Wicker Tree      2011.0
# The Wicker Tree  The Wicker Tree  The Wicker Tree      2011.0
# The Wicker Tree  The Wicker Tree  The Wicker Tree      2011.0
# The Wicker Tree  The Wicker Tree  The Wicker Tree      2011.0
# ...                          ...              ...         ...
# A Russian Youth  A Russian Youth  Malchik russkiy      2019.0
# A Russian Youth  A Russian Youth  Malchik russkiy      2019.0
# A Russian Youth  A Russian Youth  Malchik russkiy      2019.0
# A Russian Youth  A Russian Youth  Malchik russkiy      2019.0
# A Russian Youth  A Russian Youth  Malchik russkiy      2019.0
#
#                  runtime_minutes  genres  averagerating  numvotes  \
# primary_title
# The Wicker Tree             96.0   Drama            3.9    2328.0
# The Wicker Tree             96.0  Horror            3.9    2328.0
# The Wicker Tree             96.0   Drama            3.9    2328.0
# The Wicker Tree             96.0  Horror            3.9    2328.0
# The Wicker Tree             96.0   Drama            3.9    2328.0
# ...                          ...     ...            ...       ...
# A Russian Youth             72.0     War            6.6      34.0
# A Russian Youth             72.0   Drama            6.6      34.0
# A Russian Youth             72.0     War            6.6      34.0
# A Russian Youth             72.0   Drama            6.6      34.0
# A Russian Youth             72.0     War            6.6      34.0
#
#                  ratingbyvotes   movie_id
# primary_title
# The Wicker Tree       0.001675  tt0323808
# The Wicker Tree       0.001675  tt0323808
# The Wicker Tree       0.001675  tt0323808
# The Wicker Tree       0.001675  tt0323808
# The Wicker Tree       0.001675  tt0323808
# ...                        ...        ...
# A Russian Youth       0.194118  tt9681728
# A Russian Youth       0.194118  tt9681728
# A Russian Youth       0.194118  tt9681728
# A Russian Youth       0.194118  tt9681728
# A Russian Youth       0.194118  tt9681728
#
# [1024406 rows x 15 columns]

# %%
average_rating_mean = imdb_df.groupby('genres', as_index = False).mean()
average_rating_mean.sort_values(by = 'averagerating', ascending = False)
# Out:
#          genres  ordering   start_year  runtime_minutes  averagerating  \
# 6   Documentary  4.512691  2014.142230        85.958189       7.306667
# 15         News  4.351081  2013.145135        80.632973       7.273595
# 3     Biography  4.897267  2014.095546        94.585577       7.102319
# 12        Music  5.014052  2013.957712        95.060392       7.008915
# 10      History  4.888857  2013.983021        96.326854       6.968398
# 18        Sport  5.086816  2014.305149        94.864713       6.899515
# 13      Musical  5.158320  2014.008962       106.342295       6.475101
# 20          War  5.086151  2014.163040        99.283446       6.471391
# 7         Drama  5.198212  2014.237382        99.416970       6.366434
# 8        Family  5.144139  2014.174534        93.685653       6.311169
# 2     Animation  5.158344  2014.283685        86.714521       6.245968
# 16      Romance  5.258601  2014.160470       104.028387       6.134981
# 1     Adventure  5.152008  2014.335335        95.677275       6.084935
# 5         Crime  5.226809  2014.246328       100.476205       6.075704
# 4        Comedy  5.236606  2014.244817        97.961851       5.983607
# 14      Mystery  5.175801  2014.436401        96.190356       5.877782
# 9       Fantasy  5.169320  2014.257283        97.090842       5.858170
# 21      Western  5.110674  2014.357830        94.248469       5.775897
# 0        Action  5.235522  2014.295146       105.051827       5.758759
# 19     Thriller  5.212872  2014.382885        97.038782       5.593037
# 17       Sci-Fi  5.145599  2014.337343        93.338600       5.407397
# 11       Horror  5.084401  2014.330787        89.297868       4.931227
#
#         numvotes  ratingbyvotes
# 6     380.050757       0.438942
# 15    292.355135       0.437776
# 3    7434.132486       0.293645
# 12   3515.621438       0.297627
# 10   3674.123770       0.304599
# 18   4021.942051       0.247750
# 13   2424.040590       0.292186
# 20   3870.347398       0.213321
# 7    4614.757683       0.217833
# 8    3050.339245       0.247444
# 2   10976.164299       0.151889
# 16   4817.095447       0.164457
# 1   26584.926524       0.180983
# 5    9940.127251       0.155833
# 4    5175.094541       0.179869
# 14   9414.399403       0.178889
# 9   14834.097392       0.188906
# 21  10713.277340       0.211227
# 0   17452.489005       0.145919
# 19   6882.228646       0.150403
# 17  23454.102788       0.153279
# 11   3889.456781       0.147830

# %%
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(6,8)})
sns.barplot(x = 'genres', y = 'averagerating', data = average_rating_mean.head(5), color = 'red',
                           order = average_rating_mean.head(5).sort_values('averagerating',ascending = False).genres)
plt.xlabel('Genres')
plt.ylabel('Average Rating', rotation = 90)
plt.title("Genre's average rating", fontsize = 20)
plt.savefig(fname = "genre'saveragerating.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 8))
sns.barplot(x = 'genres', y = 'numvotes', data = average_rating_mean.head(), color = 'g',
                         order = average_rating_mean.head().sort_values('numvotes',ascending = False).genres)
plt.xlabel('Genres', fontsize = 15)
plt.ylabel('Average Number of Votes', fontsize = 15)
plt.title('Audience Interaction', fontsize = 20)
plt.savefig(fname = "audienceinteraction.png", bbox_inches = "tight")
plt.show()

# %%
average_budget_df = imdb_budget_df.groupby('genres', as_index = False).mean()
average_budget_df.sort_values(by = 'profit_margin', ascending = False)
# Out:
#          genres   start_year  runtime_minutes  averagerating       numvotes  \
# 2     Animation  2014.143084        93.306041       6.493482  103205.967409
# 1     Adventure  2014.244505       109.350504       6.388004  172363.627518
# 9       Fantasy  2013.788690       108.805357       6.019107  121828.050595
# 8        Family  2013.538348       103.435103       6.207006   62351.460914
# 14      Mystery  2013.937908       102.634454       6.032680   85745.464986
# 0        Action  2014.045992       110.764039       6.124363  142163.897350
# 12        Music  2013.714083       105.517781       6.472546   50956.886202
# 17       Sci-Fi  2014.313906       109.429959       6.178834  206173.396728
# 4        Comedy  2013.660592       101.715264       6.179090   69352.203343
# 16      Romance  2013.265234       105.711995       6.283547   53776.295702
# 3     Biography  2014.515249       114.288390       6.964152   83996.789727
# 11       Horror  2013.937592        95.122153       5.363472   44748.874889
# 7         Drama  2013.880804       107.748807       6.439469   58473.054029
# 19     Thriller  2013.877916       102.316243       5.840050   73106.005463
# 10      History  2014.477941       117.083824       6.828824   65598.041176
# 5         Crime  2013.734339       106.662016       6.250826   81633.275057
# 18        Sport  2013.919210       111.423698       6.580790   46695.906643
# 15         News  2013.545455        70.636364       6.809091      19.590909
# 6   Documentary  2013.822894        85.028078       7.144636    3139.865371
# 13      Musical  2013.649746       108.695431       6.409137   44004.106599
# 20          War  2013.933155       115.652406       6.493583   38805.029412
# 21      Western  2013.324324       111.229730       6.320270  137729.608108
#
#            id  production_budget  domestic_gross  worldwide_gross  \
# 2   46.825119       8.692082e+07    1.175884e+08     3.225839e+08
# 1   48.918040       9.267462e+07    1.073974e+08     3.011226e+08
# 9   50.448810       7.103324e+07    7.943705e+07     2.200906e+08
# 8   53.851770       5.469347e+07    7.206057e+07     1.700172e+08
# 14  54.106909       2.134720e+07    3.177445e+07     7.090425e+07
# 0   50.135477       6.691027e+07    7.313149e+07     1.969462e+08
# 12  58.652916       1.514410e+07    2.969315e+07     6.282952e+07
# 17  51.843558       7.191794e+07    9.364577e+07     2.532340e+08
# 4   50.835434       3.393664e+07    4.848426e+07     1.087715e+08
# 16  52.747595       2.064924e+07    2.993205e+07     6.421039e+07
# 3   51.956126       2.555116e+07    3.440162e+07     7.149720e+07
# 11  53.688849       1.823958e+07    2.884778e+07     6.563880e+07
# 7   51.164473       2.376017e+07    2.894212e+07     6.165098e+07
# 19  52.688800       2.755553e+07    3.343507e+07     8.313735e+07
# 10  47.823529       3.149279e+07    3.359664e+07     7.119663e+07
# 5   49.959567       2.791220e+07    3.056643e+07     6.671373e+07
# 18  56.037702       2.362325e+07    3.665425e+07     7.233198e+07
# 15  45.045455       1.516364e+07    8.369494e+06     3.083247e+07
# 6   46.904248       1.986271e+07    2.615663e+07     4.874498e+07
# 13  49.928934       3.690863e+07    7.509066e+07     1.702289e+08
# 20  50.799465       2.331952e+07    2.004659e+07     4.338628e+07
# 21  49.229730       5.010811e+07    4.075873e+07     8.287419e+07
#
#          revenue  profit_margin
# 2   4.095047e+08       0.659178
# 1   3.937973e+08       0.626322
# 9   2.911239e+08       0.599425
# 8   2.247107e+08       0.580204
# 14  9.225144e+07       0.564652
# 0   2.638564e+08       0.562108
# 12  7.797362e+07       0.561593
# 17  3.251520e+08       0.556912
# 4   1.427081e+08       0.553408
# 16  8.485963e+07       0.545122
# 3   9.704836e+07       0.543181
# 11  8.387837e+07       0.524367
# 7   8.541115e+07       0.503459
# 19  1.106929e+08       0.502520
# 10  1.026894e+08       0.497335
# 5   9.462593e+07       0.481328
# 18  9.595523e+07       0.472857
# 15  4.599610e+07       0.448743
# 6   6.860769e+07       0.437218
# 13  2.071376e+08       0.423858
# 20  6.670580e+07       0.407004
# 21  1.329823e+08       0.357322

# %%
fig, ax = plt.subplots(1,3)
sns.set(rc = {'figure.figsize':(20,10)})
sns.barplot(x = 'genres', y = 'profit_margin', data = average_budget_df.head(), color = 'b',
                           order = average_budget_df.head().sort_values('profit_margin',ascending = False).genres,ax=ax[0])
sns.barplot(x = 'genres', y = 'numvotes', data = average_rating_mean.head(), color = 'g',
                         order = average_rating_mean.head().sort_values('numvotes',ascending = False).genres,ax=ax[1])
sns.barplot(x = 'genres', y = 'averagerating', data = average_rating_mean.head(5), color = 'red',
                           order = average_rating_mean.head(5).sort_values('averagerating',ascending = False).genres,ax=ax[2])
ax[0].set_xlabel('Genres',fontsize = 15)
ax[1].set_xlabel('Genres',fontsize = 15)
ax[2].set_xlabel('Genres',fontsize = 15)
ax[0].set_ylabel('Profit Margin', fontsize = 15)
ax[1].set_ylabel('Number of Votes', fontsize = 15)
ax[2].set_ylabel('Average Rating', fontsize = 15)
# Out:
# Text(0, 0.5, 'Average Rating')

# %%
imdb_budget_df["day"] = imdb_budget_df['release_date'].map(lambda x: x.day)
imdb_budget_df["month"] = imdb_budget_df['release_date'].map(lambda x: x.month)
imdb_budget_df["year"] = imdb_budget_df['release_date'].map(lambda x: x.year)
imdb_budget_df
# Out:
#           movie_id  primary_title original_title  genres  start_year  \
# 40       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 41       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# 42       tt0475290  Hail, Caesar!  Hail, Caesar!   Music      2016.0
# 43       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 44       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# ...            ...            ...            ...     ...         ...
# 1026474  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026475  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026476  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026477  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026478  tt8662424    Never Again    Never Again   Drama      2017.0
#
#          runtime_minutes  averagerating  numvotes      primary_name  \
# 40                 106.0            6.3  111422.0     Roger Deakins
# 41                 106.0            6.3  111422.0     Roger Deakins
# 42                 106.0            6.3  111422.0     Roger Deakins
# 43                 106.0            6.3  111422.0       Josh Brolin
# 44                 106.0            6.3  111422.0       Josh Brolin
# ...                  ...            ...       ...               ...
# 1026474            106.0            5.7      67.0  Kristen Carletta
# 1026475            106.0            5.7      67.0        Jay Coster
# 1026476            106.0            5.7      67.0     Katie Watling
# 1026477            106.0            5.7      67.0      Ben Gordelia
# 1026478            106.0            5.7      67.0    Michael Wooley
#
#                 category    id release_date  production_budget  \
# 40       cinematographer  22.0   2016-02-05         22000000.0
# 41       cinematographer  22.0   2016-02-05         22000000.0
# 42       cinematographer  22.0   2016-02-05         22000000.0
# 43                 actor  22.0   2016-02-05         22000000.0
# 44                 actor  22.0   2016-02-05         22000000.0
# ...                  ...   ...          ...                ...
# 1026474          actress  47.0   2002-07-12           500000.0
# 1026475         director  47.0   2002-07-12           500000.0
# 1026476         producer  47.0   2002-07-12           500000.0
# 1026477         composer  47.0   2002-07-12           500000.0
# 1026478  cinematographer  47.0   2002-07-12           500000.0
#
#          domestic_gross  worldwide_gross     revenue  profit_margin  day  \
# 40           30080225.0       64160680.0  86160680.0       0.744663    5
# 41           30080225.0       64160680.0  86160680.0       0.744663    5
# 42           30080225.0       64160680.0  86160680.0       0.744663    5
# 43           30080225.0       64160680.0  86160680.0       0.744663    5
# 44           30080225.0       64160680.0  86160680.0       0.744663    5
# ...                 ...              ...         ...            ...  ...
# 1026474        307631.0         308793.0    808793.0       0.381795   12
# 1026475        307631.0         308793.0    808793.0       0.381795   12
# 1026476        307631.0         308793.0    808793.0       0.381795   12
# 1026477        307631.0         308793.0    808793.0       0.381795   12
# 1026478        307631.0         308793.0    808793.0       0.381795   12
#
#          month  year
# 40           2  2016
# 41           2  2016
# 42           2  2016
# 43           2  2016
# 44           2  2016
# ...        ...   ...
# 1026474      7  2002
# 1026475      7  2002
# 1026476      7  2002
# 1026477      7  2002
# 1026478      7  2002
#
# [60594 rows x 20 columns]

# %%
imdb_budget_df['months'] = imdb_budget_df['release_date'].dt.month_name().str[:]
imdb_budget_df
# Out:
#           movie_id  primary_title original_title  genres  start_year  \
# 40       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 41       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# 42       tt0475290  Hail, Caesar!  Hail, Caesar!   Music      2016.0
# 43       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 44       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# ...            ...            ...            ...     ...         ...
# 1026474  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026475  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026476  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026477  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026478  tt8662424    Never Again    Never Again   Drama      2017.0
#
#          runtime_minutes  averagerating  numvotes      primary_name  \
# 40                 106.0            6.3  111422.0     Roger Deakins
# 41                 106.0            6.3  111422.0     Roger Deakins
# 42                 106.0            6.3  111422.0     Roger Deakins
# 43                 106.0            6.3  111422.0       Josh Brolin
# 44                 106.0            6.3  111422.0       Josh Brolin
# ...                  ...            ...       ...               ...
# 1026474            106.0            5.7      67.0  Kristen Carletta
# 1026475            106.0            5.7      67.0        Jay Coster
# 1026476            106.0            5.7      67.0     Katie Watling
# 1026477            106.0            5.7      67.0      Ben Gordelia
# 1026478            106.0            5.7      67.0    Michael Wooley
#
#                 category  ...  release_date production_budget  domestic_gross  \
# 40       cinematographer  ...    2016-02-05        22000000.0      30080225.0
# 41       cinematographer  ...    2016-02-05        22000000.0      30080225.0
# 42       cinematographer  ...    2016-02-05        22000000.0      30080225.0
# 43                 actor  ...    2016-02-05        22000000.0      30080225.0
# 44                 actor  ...    2016-02-05        22000000.0      30080225.0
# ...                  ...  ...           ...               ...             ...
# 1026474          actress  ...    2002-07-12          500000.0        307631.0
# 1026475         director  ...    2002-07-12          500000.0        307631.0
# 1026476         producer  ...    2002-07-12          500000.0        307631.0
# 1026477         composer  ...    2002-07-12          500000.0        307631.0
# 1026478  cinematographer  ...    2002-07-12          500000.0        307631.0
#
#          worldwide_gross     revenue  profit_margin  day  month  year  \
# 40            64160680.0  86160680.0       0.744663    5      2  2016
# 41            64160680.0  86160680.0       0.744663    5      2  2016
# 42            64160680.0  86160680.0       0.744663    5      2  2016
# 43            64160680.0  86160680.0       0.744663    5      2  2016
# 44            64160680.0  86160680.0       0.744663    5      2  2016
# ...                  ...         ...            ...  ...    ...   ...
# 1026474         308793.0    808793.0       0.381795   12      7  2002
# 1026475         308793.0    808793.0       0.381795   12      7  2002
# 1026476         308793.0    808793.0       0.381795   12      7  2002
# 1026477         308793.0    808793.0       0.381795   12      7  2002
# 1026478         308793.0    808793.0       0.381795   12      7  2002
#
#            months
# 40       February
# 41       February
# 42       February
# 43       February
# 44       February
# ...           ...
# 1026474      July
# 1026475      July
# 1026476      July
# 1026477      July
# 1026478      July
#
# [60594 rows x 21 columns]

# %%
best_month_df = imdb_budget_df.groupby('months', as_index = False).mean()
best_month_df
# Out:
#        months   start_year  runtime_minutes  averagerating       numvotes  \
# 0       April  2013.839670       103.916091       6.227093   62573.368856
# 1      August  2013.736312       101.658615       6.196860   73578.618760
# 2    December  2013.881741       108.059476       6.256897   72798.294746
# 3    February  2014.254245       103.327518       6.136032   75804.922540
# 4     January  2014.087994       105.591072       6.046075   49129.148794
# 5        July  2013.773104       105.099851       6.256830  108590.215424
# 6        June  2013.874314       105.713036       6.304027  104119.164735
# 7       March  2014.082630       104.097201       6.241814   89977.758436
# 8         May  2013.814906       108.330948       6.267769  125336.762586
# 9    November  2013.954924       109.017235       6.508409  119765.775189
# 10    October  2013.783702       106.856864       6.245722   79753.783525
# 11  September  2013.711231       103.060875       6.206357   72195.029667
#
#            id  production_budget  domestic_gross  worldwide_gross  \
# 0   49.697581       3.007457e+07    3.720952e+07     9.713190e+07
# 1   55.121981       2.898987e+07    3.420123e+07     7.277918e+07
# 2   51.893248       3.379236e+07    4.266593e+07     1.037712e+08
# 3   53.899046       3.522255e+07    4.710719e+07     1.029463e+08
# 4   55.668548       2.680779e+07    3.260607e+07     7.161004e+07
# 5   50.659018       4.743107e+07    6.115149e+07     1.606204e+08
# 6   52.078300       5.741391e+07    8.053780e+07     1.992013e+08
# 7   51.377109       4.946586e+07    6.000928e+07     1.438677e+08
# 8   47.865745       6.485966e+07    7.335960e+07     1.952627e+08
# 9   46.823106       5.064414e+07    6.740193e+07     1.760020e+08
# 10  50.631178       2.565198e+07    2.727323e+07     6.979268e+07
# 11  49.752841       2.549966e+07    2.656269e+07     5.926530e+07
#
#          revenue  profit_margin        day  month         year
# 0   1.272065e+08       0.538491  15.825077    4.0  2011.947773
# 1   1.017691e+08       0.526730  15.639090    8.0  2010.387279
# 2   1.375635e+08       0.470402  20.179260   12.0  2010.916955
# 3   1.381688e+08       0.556900  13.002791    2.0  2009.644103
# 4   9.841783e+07       0.546653  17.450231    1.0  2011.536429
# 5   2.080514e+08       0.571765  16.229658    7.0  2010.197578
# 6   2.566153e+08       0.570093  15.405939    6.0  2010.864958
# 7   1.933335e+08       0.530293  16.228528    3.0  2013.133052
# 8   2.601224e+08       0.549971  15.312932    5.0  2011.734452
# 9   2.266461e+08       0.592526  14.536742   11.0  2011.003409
# 10  9.544466e+07       0.516377  14.976439   10.0  2010.754473
# 11  8.476496e+07       0.506761  16.711424    9.0  2011.764015

# %%
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,8)})
sns.lineplot(x = 'months', y = 'profit_margin', data = best_month_df.sort_values(by = 'month') , color = 'b')
ax.tick_params(labelsize = 18)
plt.xlabel('Month', fontsize = 22)
plt.ylabel('Profit Margin', fontsize = 22)
plt.title('Average profit margin by month', fontsize = 25)
plt.savefig(fname = 'Averageprofitmargin.png')
plt.show()

# %%
sg_df = imdb_budget_df.loc[imdb_budget_df['genres'].isin(["Musical", "Family", "Animation", "Action", "Adventure", "Fantasy", "Scifi"])]

# %%
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,8)})
sns.violinplot(x = 'genres', y = 'month', data = sg_df.sort_values(by = 'months') , color = 'b')
plt.xlabel('Genre', fontsize = 15)
plt.ylabel('Month', fontsize = 15)
plt.title('Release Months by Genre', fontsize = 20)
plt.show()

# %%
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,8)})
sns.violinplot(x = 'genres', y = 'month', data = sg_df.sort_values(by = 'month') , color = 'b')
plt.xlabel('Genre', fontsize = 15)
plt.ylabel('Month', fontsize = 15)
plt.title('Release Months by Genre', fontsize = 20)
plt.show()

# %%
imdb_budget_df
# Out:
#           movie_id  primary_title original_title  genres  start_year  \
# 40       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 41       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# 42       tt0475290  Hail, Caesar!  Hail, Caesar!   Music      2016.0
# 43       tt0475290  Hail, Caesar!  Hail, Caesar!  Comedy      2016.0
# 44       tt0475290  Hail, Caesar!  Hail, Caesar!   Drama      2016.0
# ...            ...            ...            ...     ...         ...
# 1026474  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026475  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026476  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026477  tt8662424    Never Again    Never Again   Drama      2017.0
# 1026478  tt8662424    Never Again    Never Again   Drama      2017.0
#
#          runtime_minutes  averagerating  numvotes      primary_name  \
# 40                 106.0            6.3  111422.0     Roger Deakins
# 41                 106.0            6.3  111422.0     Roger Deakins
# 42                 106.0            6.3  111422.0     Roger Deakins
# 43                 106.0            6.3  111422.0       Josh Brolin
# 44                 106.0            6.3  111422.0       Josh Brolin
# ...                  ...            ...       ...               ...
# 1026474            106.0            5.7      67.0  Kristen Carletta
# 1026475            106.0            5.7      67.0        Jay Coster
# 1026476            106.0            5.7      67.0     Katie Watling
# 1026477            106.0            5.7      67.0      Ben Gordelia
# 1026478            106.0            5.7      67.0    Michael Wooley
#
#                 category  ...  release_date production_budget  domestic_gross  \
# 40       cinematographer  ...    2016-02-05        22000000.0      30080225.0
# 41       cinematographer  ...    2016-02-05        22000000.0      30080225.0
# 42       cinematographer  ...    2016-02-05        22000000.0      30080225.0
# 43                 actor  ...    2016-02-05        22000000.0      30080225.0
# 44                 actor  ...    2016-02-05        22000000.0      30080225.0
# ...                  ...  ...           ...               ...             ...
# 1026474          actress  ...    2002-07-12          500000.0        307631.0
# 1026475         director  ...    2002-07-12          500000.0        307631.0
# 1026476         producer  ...    2002-07-12          500000.0        307631.0
# 1026477         composer  ...    2002-07-12          500000.0        307631.0
# 1026478  cinematographer  ...    2002-07-12          500000.0        307631.0
#
#          worldwide_gross     revenue  profit_margin  day  month  year  \
# 40            64160680.0  86160680.0       0.744663    5      2  2016
# 41            64160680.0  86160680.0       0.744663    5      2  2016
# 42            64160680.0  86160680.0       0.744663    5      2  2016
# 43            64160680.0  86160680.0       0.744663    5      2  2016
# 44            64160680.0  86160680.0       0.744663    5      2  2016
# ...                  ...         ...            ...  ...    ...   ...
# 1026474         308793.0    808793.0       0.381795   12      7  2002
# 1026475         308793.0    808793.0       0.381795   12      7  2002
# 1026476         308793.0    808793.0       0.381795   12      7  2002
# 1026477         308793.0    808793.0       0.381795   12      7  2002
# 1026478         308793.0    808793.0       0.381795   12      7  2002
#
#            months
# 40       February
# 41       February
# 42       February
# 43       February
# 44       February
# ...           ...
# 1026474      July
# 1026475      July
# 1026476      July
# 1026477      July
# 1026478      July
#
# [60594 rows x 21 columns]

# %%
profit_margin_index = imdb_budget_df.groupby(['genres','months'],as_index=False).mean().sort_values(by = 'profit_margin', ascending = False)
profit_margin_index
# Out:
#         genres    months   start_year  runtime_minutes  averagerating  \
# 209      Sport   January  2016.000000        99.428571       3.614286
# 147      Music  February  2012.750000       121.000000       5.050000
# 29   Animation      July  2013.750000        91.916667       6.191667
# 152      Music       May  2017.000000       118.000000       7.050000
# 164    Musical  November  2013.666667       110.333333       6.666667
# ..         ...       ...          ...              ...            ...
# 236        War       May  2012.000000       123.500000       6.000000
# 159    Musical   January  2013.000000       165.000000       7.800000
# 128    History       May  2013.000000       125.000000       6.200000
# 242    Western  February  2015.000000        90.000000       6.300000
# 156    Musical    August  2016.000000        97.000000       6.900000
#
#           numvotes    id  production_budget  domestic_gross  worldwide_gross  \
# 209     451.857143  50.0       5.000000e+06    1.381416e+08     2.789648e+08
# 147   58836.500000  35.5       1.127500e+07    4.582906e+07     6.333301e+07
# 29   140402.583333  37.0       8.283333e+07    1.771947e+08     5.700559e+08
# 152   77479.000000  42.5       3.500000e+07    1.208195e+08     1.981341e+08
# 164  103132.333333  63.0       2.866667e+07    1.512736e+08     2.536866e+08
# ..             ...   ...                ...             ...              ...
# 236    2562.500000  16.0       2.300000e+07    6.214030e+05     2.097231e+06
# 159    2446.000000  25.0       1.400000e+07    2.742990e+05     2.742990e+05
# 128     799.000000  11.0       1.000000e+07    1.734720e+05     1.734720e+05
# 242    9199.000000  54.0       1.800000e+07    0.000000e+00     0.000000e+00
# 156     534.000000  87.0       5.000000e+05    0.000000e+00     0.000000e+00
#
#           revenue  profit_margin        day  month         year
# 209  2.839648e+08       0.982392  20.000000    1.0  2017.000000
# 147  7.460801e+07       0.844453  10.250000    2.0  2006.000000
# 29   6.528893e+08       0.831483  16.500000    7.0  2013.750000
# 152  2.331341e+08       0.817212  23.000000    5.0  2017.000000
# 164  2.823533e+08       0.813259  13.666667   11.0  2005.333333
# ..            ...            ...        ...    ...          ...
# 236  2.509723e+07       0.058762   4.500000    5.0  2012.000000
# 159  1.427430e+07       0.019216  24.000000    1.0  2003.000000
# 128  1.017347e+07       0.017051   3.000000    5.0  2013.000000
# 242  1.800000e+07       0.000000  19.000000    2.0  2016.000000
# 156  5.000000e+05       0.000000  11.000000    8.0  2015.000000
#
# [249 rows x 15 columns]

# %%
profit_month_genre = ['Animation','Comedy','Action','Adventure']
genre_short_list = profit_margin_index[profit_margin_index['genres'].isin(profit_month_genre)].sort_values(by = 'month')

# %%
sns.set(rc = {'figure.figsize':(20,8)})
sns.lineplot(x = 'months', y = 'profit_margin', data = genre_short_list, hue=genre_short_list['genres'])
plt.title("Genre's Average Profit Margin by Month", fontsize = 20)
plt.xlabel('Month', fontsize = 17)
plt.ylabel('Profit Margin', fontsize = 17)
# Out:
# Text(0, 0.5, 'Profit Margin')

# %%
sns.set(rc = {'figure.figsize':(20,8)})
sns.barplot(x = 'months', y = 'profit_margin', data = genre_short_list, hue=genre_short_list['genres'])
plt.title("Genre's Average Profit Margin by Month", fontsize = 20)
plt.xlabel('Month', fontsize = 17)
plt.ylabel('Profit Margin', fontsize = 17)
# Out:
# Text(0, 0.5, 'Profit Margin')
